# %% [markdown]
# # This code generates a file structure

# %%
from pathlib import Path

# =========================================
# CONFIG
# =========================================
ROOT_DIR = Path(".")

EXCLUDE_DIRS = {
    "__pycache__",
    ".git",
    "node_modules",
    "image"          # hides dataset image contents
}

EXCLUDE_EXTENSIONS = {
    ".jpg",
    ".jpeg",
    ".png",
    ".webp",
    ".gif",
    ".pyc",
    ".txt"
}

# =========================================
# TREE GENERATOR
# =========================================
def generate_tree(path: Path, prefix=""):
    entries = sorted(
        [p for p in path.iterdir()
         if p.name not in EXCLUDE_DIRS
         and p.suffix.lower() not in EXCLUDE_EXTENSIONS],
        key=lambda x: (x.is_file(), x.name.lower())
    )

    for i, entry in enumerate(entries):
        connector = "└── " if i == len(entries) - 1 else "├── "

        print(prefix + connector + entry.name)

        if entry.is_dir():
            extension = "    " if i == len(entries) - 1 else "│   "
            generate_tree(entry, prefix + extension)

# =========================================
# RUN
# =========================================
print(ROOT_DIR.resolve().name)
generate_tree(ROOT_DIR)
# Out:
# YOLOvsLLAVAcomparison
# ├── data
# │   ├── inspection_dataset
# │   │   ├── images
# │   │   │   ├── all
# │   │   │   ├── test
# │   │   │   ├── train
# │   │   │   └── val
# │   │   ├── labels
# │   │   │   ├── all
# │   │   │   ├── test
# │   │   │   ├── train
# │   │   │   └── val
# │   │   └── data.yaml
# │   ├── jobs
# │   ├── Original data folders
# │   │   ├── asbestos
# │   │   │   ├── test
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   ├── train
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   ├── valid
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   └── data.yaml
# │   │   ├── crack
# │   │   │   ├── test
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   ├── train
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   ├── valid
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   └── data.yaml
# │   │   ├── house
# │   │   │   ├── test
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   ├── train
# │   │   │   │   ├── images
# │   │   │   │   └── labels
# │   │   │   └── data.yaml
# │   │   ├── mold
# │   │   │   ├── train
# │   │   │   └── data.yaml
# │   │   └── paint
# │   │       ├── test
# │   │       │   ├── images
# │   │       │   └── labels
# │   │       └── data.yaml
# │   └── properties
# │       ├── 001
# │       │   ├── post_lease
# │       │   ├── pre_lease
# │       │   └── old_report.json
# │       ├── 002
# │       │   ├── post_lease
# │       │   ├── pre_lease
# │       │   └── old_report.json
# │       ├── 003
# │       │   ├── post_lease
# │       │   ├── pre_lease
# │       │   └── old_report.json
# │       ├── 004
# │       │   ├── post_lease
# │       │   ├── pre_lease
# │       │   └── old_report.json
# │       ├── 005
# │       │   ├── post_lease
# │       │   ├── pre_lease
# │       │   └── old_report.json
# │       └── 006
# │           ├── post_lease
# │           ├── pre_lease
# │           └── old_report.json
# ├── results
# │   ├── 001_result.json
# │   ├── 003_result.json
# │   └── 004_result.json
# ├── src
# │   ├── eval
# │   │   └── evaluate.py
# │   ├── pipelines
# │   │   ├── llava_pipeline.py
# │   │   └── yolo_pipeline.py
# │   ├── postprocess
# │   │   ├── aggregate_property.py
# │   │   ├── compare.py
# │   │   └── normalize.py
# │   ├── preprocess
# │   │   ├── build_fake_properties_from_zip.py
# │   │   ├── check_mold_labels.py
# │   │   ├── create_and_split_dataset.py
# │   │   └── dataset_mapping.py
# │   ├── config.py
# │   ├── schemas.py
# │   └── train_yolo.py
# ├── file structure generator.ipynb
# └── run_property.py
